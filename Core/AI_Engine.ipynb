# %% [markdown]
# # AI Engine

# %%
# !pip install langchain_ollama
# Out:
# Collecting langchain_ollama
#   Downloading langchain_ollama-1.0.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain_ollama) (1.2.9)
# Collecting ollama<1.0.0,>=0.6.0 (from langchain_ollama)
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.6.9)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (9.1.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.14.0)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama<1.0.0,>=0.6.0->langchain_ollama) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.32.4)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.5.0)
# Downloading langchain_ollama-1.0.1-py3-none-any.whl (29 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama, langchain_ollama
# Successfully installed langchain_ollama-1.0.1 ollama-0.6.1

# %%
from langchain_ollama.llms import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate

# %%
model=OllamaLLM(model="gemma3:4b")

# %%
template=''' you are an expert in answering questions about a pizaa restaurant
Here are some relevant reviews : {reviews}
Here is  the question to  answer : {question} '''

# %%
prompt=ChatPromptTemplate.from_template(template)
chain = prompt | model
chain.invoke({"reviews":[],"question":"what is the best pzza place in the town"})
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     100     try:
# --> 101         yield
#     102     except Exception as exc:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     100             self._connect_failed = True
# --> 101             raise exc
#     102
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      77                 if self._connection is None:
# ---> 78                     stream = self._connect(request)
#      79
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in _connect(self, request)
#     123                     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124                         stream = self._network_backend.connect_tcp(**kwargs)
#     125                         trace.return_value = stream
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_backends/sync.py in connect_tcp(self, host, port, timeout, local_address, socket_options)
#     206
# --> 207         with map_exceptions(exc_map):
#     208             sock = socket.create_connection(
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     157             try:
# --> 158                 self.gen.throw(value)
#     159             except StopIteration as exc:
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# /tmp/ipython-input-3932252210.py in <cell line: 0>()
#       1 prompt=ChatPromptTemplate.from_template(template)
#       2 chain = prompt | model
# ----> 3 chain.invoke({"reviews":[],"question":"what is the best pzza place in the town"})
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3151                         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3152                     else:
# -> 3153                         input_ = context.run(step.invoke, input_, config)
#    3154         # finish the root run
#    3155         except BaseException as e:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in invoke(self, input, config, stop, **kwargs)
#     376         config = ensure_config(config)
#     377         return (
# --> 378             self.generate_prompt(
#     379                 [self._convert_input(input)],
#     380                 stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     787     ) -> LLMResult:
#     788         prompt_strings = [p.to_string() for p in prompts]
# --> 789         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     790
#     791     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1009                 )
#    1010             ]
# -> 1011             return self._generate_helper(
#    1012                 prompts,
#    1013                 stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     813         try:
#     814             output = (
# --> 815                 self._generate(
#     816                     prompts,
#     817                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_ollama/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     454         generations = []
#     455         for prompt in prompts:
# --> 456             final_chunk = self._stream_with_aggregation(
#     457                 prompt,
#     458                 stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_ollama/llms.py in _stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     413         final_chunk = None
#     414         thinking_content = ""
# --> 415         for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     416             if not isinstance(stream_resp, str):
#     417                 if stream_resp.get("thinking"):
#
# /usr/local/lib/python3.12/dist-packages/langchain_ollama/llms.py in _create_generate_stream(self, prompt, stop, **kwargs)
#     357     ) -> Iterator[Mapping[str, Any] | str]:
#     358         if self._client:
# --> 359             yield from self._client.generate(
#     360                 **self._generate_params(prompt, stop=stop, **kwargs)
#     361             )
#
# /usr/local/lib/python3.12/dist-packages/ollama/_client.py in inner()
#     172
#     173       def inner():
# --> 174         with self._client.stream(*args, **kwargs) as r:
#     175           try:
#     176             r.raise_for_status()
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     866             extensions=extensions,
#     867         )
# --> 868         response = self.send(
#     869             request=request,
#     870             auth=auth,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     247             extensions=request.extensions,
#     248         )
# --> 249         with map_httpcore_exceptions():
#     250             resp = self._pool.handle_request(req)
#     251
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     156                 value = typ()
#     157             try:
# --> 158                 self.gen.throw(value)
#     159             except StopIteration as exc:
#     160                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     116
#     117         message = str(exc)
# --> 118         raise mapped_exc(message) from exc
#     119
#     120
#
# ConnectError: [Errno 111] Connection refused
